# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import tensorflow
tensorflow.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From <ipython-input-2-cff5e14f5db6>:2: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# True

# %%
# 이미지 처리
import cv2
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
# json 파일 처리
import json

# %%
# 파일 존재 여부 확인용
import os

# %%
# Train 데이터에서 훈련용 데이터와 검증용 데이터 분리
from sklearn.model_selection import train_test_split

# %%
# 모델
from tensorflow import keras

# %%
# 랜덤숫자 생성
import random

# %% [markdown]
# # 변수 목록

# %%
os.chdir('/content/drive/MyDrive/[perst]데이터셋/MachineLearningProject/02_Fashion Type Classification Model')

# %%
train_dir_name = "./Dataset/Train-Test/Female/Train/"
test_dir_name = "./Dataset/Train-Test/Female/Test/"

img_width = 200
img_height = 200

model_dir_name = './Model/' # 학습 모델이 저장될 디렉토리명

# %%
label_name = ['Traditional',
              'Manish',
              'Feminine',
              'Ethnic',
              'Contemporary',
              'Natural',
              'Gender-Fluid',
              'Sporty',
              'Subculture',
              'Casual']

# %% [markdown]
# # 모델이 덮어쓰기되지 않도록 이름 잊지말고 바꿔주기

# %%
model_path = model_dir_name + 'fashion_classification_female_0125_06.keras'

# %% [markdown]
# # Train-Test 데이터 불러오기

# %%
x_train = []
y_train = []

for i in range(0, 8001):
    img_path = train_dir_name + "Image/" + str(i) + ".jpg"
    label_path = train_dir_name + "Json/" + str(i) + ".json"

    if not os.path.isfile(img_path):
        continue
    if not os.path.isfile(label_path):
        continue

    # 이미지 파일 로드
    img_file = cv2.imread(img_path)
    if img_file is None:
        print(str(i) + ".jpg File Load Failed!!")
        break

    # json 파일 로드
    with open(label_path, "r") as loadfile:
      label_file = json.load(loadfile)
    if label_file is None:
        print(str(i) + ".json File Load Failed!!")
        break


    x_train.append(img_file)
    y_train.append(label_file)


    if len(y_train)%500 == 0: # 진행도 확인용
        print(str(len(y_train)) + "개 파일 읽기 완료")


print("Complete")
# Out:
# 500개 파일 읽기 완료
# 1000개 파일 읽기 완료
# 1500개 파일 읽기 완료
# 2000개 파일 읽기 완료
# 2500개 파일 읽기 완료
# 3000개 파일 읽기 완료
# 3500개 파일 읽기 완료
# 4000개 파일 읽기 완료
# 4500개 파일 읽기 완료
# 5000개 파일 읽기 완료
# 5500개 파일 읽기 완료
# 6000개 파일 읽기 완료
# 6500개 파일 읽기 완료
# 7000개 파일 읽기 완료
# 7500개 파일 읽기 완료
# 8000개 파일 읽기 완료
# Complete

# %%
x_test = []
y_test = []

for i in range(0, 2001):
    img_path = test_dir_name + "Image/" + str(i) + ".jpg"
    label_path = test_dir_name + "Json/" + str(i) + ".json"

    if not os.path.isfile(img_path):
        continue
    if not os.path.isfile(label_path):
        continue

    # 이미지 파일 로드
    img_file = cv2.imread(img_path)
    if img_file is None:
        print(str(i) + ".jpg File Load Failed!!")
        break

    # json 파일 로드
    with open(label_path, "r") as loadfile:
      label_file = json.load(loadfile)
    if label_file is None:
        print(str(i) + ".json File Load Failed!!")
        break


    x_test.append(img_file)
    y_test.append(label_file)


    if len(y_test)%500 == 0: # 진행도 확인용
        print(str(len(y_test)) + "개 파일 읽기 완료")


print("Complete")
# Out:
# 500개 파일 읽기 완료
# 1000개 파일 읽기 완료
# 1500개 파일 읽기 완료
# 2000개 파일 읽기 완료
# Complete

# %% [markdown]
# # 학습을 위해 X,Y데이터 형식 변경

# %%
x_train = np.array(x_train)
x_train.shape
# Out:
# (8000, 200, 200, 3)

# %%
x_test = np.array(x_test)
x_test.shape
# Out:
# (2000, 200, 200, 3)

# %%
y_train_ori = y_train[:]
y_train = []

for item in y_train_ori:
  num = label_name.index(item['Labeling'])
  y_train.append(num)

print(y_train[0])
# Out:
# 8

# %%
y_test_ori = y_test[:]
y_test = []

for item in y_test_ori:
  num = label_name.index(item['Labeling'])
  y_test.append(num)

print(y_test[0])
# Out:
# 8

# %%
y_train = np.array(y_train)
y_train.shape
# Out:
# (8000,)

# %%
y_train = y_train.astype('uint8')
y_train.dtype
# Out:
# dtype('uint8')

# %%
y_test = np.array(y_test)
y_test.shape
# Out:
# (2000,)

# %%
y_test = y_test.astype('uint8')
y_test.dtype
# Out:
# dtype('uint8')

# %% [markdown]
# # Train 데이터에서 Validation 데이터 분리

# %%
x_train_ori = x_train[:]
y_train_ori = y_train[:]

x_train = []
y_train = []
x_val = []
y_val = []

x_train, x_val, y_train, y_val = train_test_split(x_train_ori, y_train_ori, test_size=0.25, stratify=y_train_ori)

# %%
x_train.shape
# Out:
# (6000, 200, 200, 3)

# %%
y_train.shape
# Out:
# (6000,)

# %%
x_val.shape
# Out:
# (2000, 200, 200, 3)

# %%
y_val.shape
# Out:
# (2000,)

# %% [markdown]
# # 학습 데이터 통계

# %%
# 라벨 개수 카운트
label_count = {}

for item in y_train:
    label = label_name[item]
    if label not in label_count: # 해당 키가 없을 경우
        label_count[label] = 1
    else:
        label_count[label] = label_count[label]+1


# 내림차순 정렬
label_count = sorted(label_count.items(), key= lambda item:item[1], reverse=True)

label_count_labels = []
label_count_values = []

for item in label_count:
    label_count_labels.append(item[0])
    label_count_values.append(item[1])


# 파이 차트를 위한 라벨링 생성
total = np.sum(label_count_values)
label_count_labels_ratio = []

for i in range(0, len(label_count_labels)):
    ratio = (label_count_values[i]/total) * 100

    new_label = label_count_labels[i] + (' %.1f%%' % ratio)
    label_count_labels_ratio.append(new_label)


# 차트 그리기
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
barplot = plt.bar(label_count_labels, label_count_values)
plt.xticks(rotation=90)

for i, j in enumerate(barplot) :
    plt.text(i, j.get_height() + 0.5, label_count_values[i], ha = 'center')

plt.subplot(1, 2, 2)
plt.pie(label_count_values, startangle=90, counterclock=False)
plt.legend(label_count_labels_ratio, loc=(1.0, 0.3))

plt.title("Train Data Labeling Count")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7fe3aa95053a> in <cell line: 4>()
#       2 label_count = {}
#       3
# ----> 4 for item in y_train:
#       5     label = label_name[item]
#       6     if label not in label_count: # 해당 키가 없을 경우
#
# NameError: name 'y_train' is not defined

# %%
# 라벨 개수 카운트
label_count = {}

for item in y_val:
  label = label_name[item]
  if label not in label_count: # 해당 키가 없을 경우
    label_count[label] = 1
  else:
    label_count[label] = label_count[label]+1


# 내림차순 정렬
label_count = sorted(label_count.items(), key= lambda item:item[1], reverse=True)

label_count_labels = []
label_count_values = []

for item in label_count:
    label_count_labels.append(item[0])
    label_count_values.append(item[1])


# 파이 차트를 위한 라벨링 생성
total = np.sum(label_count_values)
label_count_labels_ratio = []

for i in range(0, len(label_count_labels)):
    ratio = (label_count_values[i]/total) * 100

    new_label = label_count_labels[i] + (' %.1f%%' % ratio)
    label_count_labels_ratio.append(new_label)


# 차트 그리기
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
barplot = plt.bar(label_count_labels, label_count_values)
plt.xticks(rotation=90)

for i, j in enumerate(barplot) :
    plt.text(i, j.get_height() + 0.5, label_count_values[i], ha = 'center')

plt.subplot(1, 2, 2)
plt.pie(label_count_values, startangle=90, counterclock=False)
plt.legend(label_count_labels_ratio, loc=(1.0, 0.3))

plt.title("Validation Data Labeling Count")
plt.show()

# %%
# 라벨 개수 카운트
label_count = {}

for item in y_test:
  label = label_name[item]
  if label not in label_count: # 해당 키가 없을 경우
    label_count[label] = 1
  else:
    label_count[label] = label_count[label]+1


# 내림차순 정렬
label_count = sorted(label_count.items(), key= lambda item:item[1], reverse=True)

label_count_labels = []
label_count_values = []

for item in label_count:
    label_count_labels.append(item[0])
    label_count_values.append(item[1])


# 파이 차트를 위한 라벨링 생성
total = np.sum(label_count_values)
label_count_labels_ratio = []

for i in range(0, len(label_count_labels)):
    ratio = (label_count_values[i]/total) * 100

    new_label = label_count_labels[i] + (' %.1f%%' % ratio)
    label_count_labels_ratio.append(new_label)


# 차트 그리기
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
barplot = plt.bar(label_count_labels, label_count_values)
plt.xticks(rotation=90)

for i, j in enumerate(barplot) :
    plt.text(i, j.get_height() + 0.5, label_count_values[i], ha = 'center')

plt.subplot(1, 2, 2)
plt.pie(label_count_values, startangle=90, counterclock=False)
plt.legend(label_count_labels_ratio, loc=(1.0, 0.3))

plt.title("Test Data Labeling Count")
plt.show()

# %% [markdown]
# # 모델 생성

# %%
input_img = keras.layers.Input(shape=(img_height, img_width, 3))

conv1 = keras.layers.Conv2D(filters=64, kernel_size=5, padding='same', activation='relu')(input_img)
conv1 = keras.layers.Dropout(0.3)(conv1)
conv1 = keras.layers.Conv2D(filters=64, kernel_size=3, padding='same', activation='relu')(conv1)
pool1 = keras.layers.MaxPooling2D(2)(conv1)

conv2 = keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(pool1)
conv2 = keras.layers.Dropout(0.3)(conv2)
conv2 = keras.layers.Conv2D(filters=128, kernel_size=3, padding='same', activation='relu')(conv2)
pool2 = keras.layers.MaxPooling2D(2)(conv2)

conv3 = keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(pool2)
conv3 = keras.layers.Dropout(0.4)(conv3)
conv3 = keras.layers.Conv2D(filters=256, kernel_size=3, padding='same', activation='relu')(conv3)
pool3 = keras.layers.MaxPooling2D(2)(conv3)

conv4 = keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(pool3)
conv4 = keras.layers.Dropout(0.4)(conv4)
conv4 = keras.layers.Conv2D(filters=512, kernel_size=3, padding='same', activation='relu')(conv4)
pool4 = keras.layers.MaxPooling2D(2)(conv4)

flat = keras.layers.Flatten()(pool4)

dense1 = keras.layers.Dense(1000, activation='relu')(flat)
dense1 = keras.layers.Dropout(0.4)(dense1)

dense2 = keras.layers.Dense(1000, activation='relu')(dense1)
dense2 = keras.layers.Dropout(0.4)(dense2)

dense3 = keras.layers.Dense(1000, activation='relu')(dense2)
dense3 = keras.layers.Dropout(0.4)(dense3)

dense4 = keras.layers.Dense(1000, activation='relu')(dense3)
dense4 = keras.layers.Dropout(0.4)(dense4)

dense5 = keras.layers.Dense(1000, activation='relu')(dense4)
dense5 = keras.layers.Dropout(0.4)(dense5)

# 모델이 총 10개의 패션 타입을 분류하므로 마지막 층은 n개의 뉴런 설정
output_label = keras.layers.Dense(10, activation='softmax', name='OutputLayer')(dense5)


fashion_model = keras.Model(input_img, output_label)
# adam learning_rate 기본값 0.001
adam = keras.optimizers.Adam(learning_rate=0.00017)
fashion_model.compile(optimizer=adam, loss='sparse_categorical_crossentropy', metrics=[keras.metrics.SparseCategoricalAccuracy()])

# %%
fashion_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  conv2d_8 (Conv2D)           (None, 200, 200, 64)      4864
#
#  dropout_9 (Dropout)         (None, 200, 200, 64)      0
#
#  conv2d_9 (Conv2D)           (None, 200, 200, 64)      36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 100, 100, 64)      0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 100, 100, 128)     73856
#
#  dropout_10 (Dropout)        (None, 100, 100, 128)     0
#
#  conv2d_11 (Conv2D)          (None, 100, 100, 128)     147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 50, 50, 128)       0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 50, 50, 256)       295168
#
#  dropout_11 (Dropout)        (None, 50, 50, 256)       0
#
#  conv2d_13 (Conv2D)          (None, 50, 50, 256)       590080
#
#  max_pooling2d_6 (MaxPoolin  (None, 25, 25, 256)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 512)       1180160
#
#  dropout_12 (Dropout)        (None, 25, 25, 512)       0
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 512)       2359808
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 512)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 73728)             0
#
#  dense_5 (Dense)             (None, 1000)              73729000
#
#  dropout_13 (Dropout)        (None, 1000)              0
#
#  dense_6 (Dense)             (None, 1000)              1001000
#
#  dropout_14 (Dropout)        (None, 1000)              0
#
#  dense_7 (Dense)             (None, 1000)              1001000
#
#  dropout_15 (Dropout)        (None, 1000)              0
#
#  dense_8 (Dense)             (None, 1000)              1001000
#
#  dropout_16 (Dropout)        (None, 1000)              0
#
#  dense_9 (Dense)             (None, 1000)              1001000
#
#  dropout_17 (Dropout)        (None, 1000)              0
#
#  OutputLayer (Dense)         (None, 10)                10010
#
# =================================================================
# Total params: 82431458 (314.45 MB)
# Trainable params: 82431458 (314.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# # 모델 학습

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint(model_path, save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
history = fashion_model.fit(x_train, y_train,
                            epochs=50, verbose=1,
                            validation_data=(x_val, y_val),
                            callbacks=[checkpoint_cb, early_stopping_cb])

print()
print("Complete")
# Out:
# Epoch 1/50
# 188/188 [==============================] - 116s 588ms/step - loss: 3.4372 - sparse_categorical_accuracy: 0.1067 - val_loss: 2.3026 - val_sparse_categorical_accuracy: 0.1005
# Epoch 2/50
# 188/188 [==============================] - 83s 442ms/step - loss: 2.3030 - sparse_categorical_accuracy: 0.0958 - val_loss: 2.3026 - val_sparse_categorical_accuracy: 0.1025
# Epoch 3/50
# 188/188 [==============================] - 83s 439ms/step - loss: 2.3030 - sparse_categorical_accuracy: 0.0970 - val_loss: 2.3026 - val_sparse_categorical_accuracy: 0.1000
# Epoch 4/50
# 188/188 [==============================] - 87s 466ms/step - loss: 2.3031 - sparse_categorical_accuracy: 0.0973 - val_loss: 2.3026 - val_sparse_categorical_accuracy: 0.1000
# Epoch 5/50
# 188/188 [==============================] - 114s 609ms/step - loss: 2.3025 - sparse_categorical_accuracy: 0.1013 - val_loss: 2.3026 - val_sparse_categorical_accuracy: 0.0985
# Epoch 6/50
# 188/188 [==============================] - 88s 468ms/step - loss: 2.3034 - sparse_categorical_accuracy: 0.0913 - val_loss: 2.3027 - val_sparse_categorical_accuracy: 0.1000
# Epoch 7/50
# 188/188 [==============================] - 88s 467ms/step - loss: 2.3028 - sparse_categorical_accuracy: 0.1020 - val_loss: 2.3027 - val_sparse_categorical_accuracy: 0.1000
# Epoch 8/50
# 188/188 [==============================] - 83s 439ms/step - loss: 2.3031 - sparse_categorical_accuracy: 0.1005 - val_loss: 2.3027 - val_sparse_categorical_accuracy: 0.1000
# Epoch 9/50
# 188/188 [==============================] - 119s 634ms/step - loss: 2.3019 - sparse_categorical_accuracy: 0.1048 - val_loss: 2.3025 - val_sparse_categorical_accuracy: 0.1000
# Epoch 10/50
# 188/188 [==============================] - 133s 710ms/step - loss: 2.2970 - sparse_categorical_accuracy: 0.1170 - val_loss: 2.2942 - val_sparse_categorical_accuracy: 0.1470
# Epoch 11/50
# 188/188 [==============================] - 83s 442ms/step - loss: 2.2892 - sparse_categorical_accuracy: 0.1207 - val_loss: 2.2975 - val_sparse_categorical_accuracy: 0.1180
# Epoch 12/50
# 188/188 [==============================] - 125s 668ms/step - loss: 2.2782 - sparse_categorical_accuracy: 0.1372 - val_loss: 2.2798 - val_sparse_categorical_accuracy: 0.1395
# Epoch 13/50
# 188/188 [==============================] - 83s 441ms/step - loss: 2.2646 - sparse_categorical_accuracy: 0.1357 - val_loss: 2.2874 - val_sparse_categorical_accuracy: 0.1380
# Epoch 14/50
# 188/188 [==============================] - 123s 654ms/step - loss: 2.2568 - sparse_categorical_accuracy: 0.1433 - val_loss: 2.2646 - val_sparse_categorical_accuracy: 0.1425
# Epoch 15/50
# 188/188 [==============================] - 83s 440ms/step - loss: 2.2338 - sparse_categorical_accuracy: 0.1528 - val_loss: 2.2676 - val_sparse_categorical_accuracy: 0.1245
# Epoch 16/50
# 188/188 [==============================] - 124s 659ms/step - loss: 2.2139 - sparse_categorical_accuracy: 0.1563 - val_loss: 2.2462 - val_sparse_categorical_accuracy: 0.1485
# Epoch 17/50
# 188/188 [==============================] - 83s 439ms/step - loss: 2.1930 - sparse_categorical_accuracy: 0.1668 - val_loss: 2.2581 - val_sparse_categorical_accuracy: 0.1405
# Epoch 18/50
# 188/188 [==============================] - 123s 655ms/step - loss: 2.1468 - sparse_categorical_accuracy: 0.1913 - val_loss: 2.2140 - val_sparse_categorical_accuracy: 0.1740
# Epoch 19/50
# 188/188 [==============================] - 129s 688ms/step - loss: 2.1125 - sparse_categorical_accuracy: 0.2043 - val_loss: 2.1955 - val_sparse_categorical_accuracy: 0.1865
# Epoch 20/50
# 188/188 [==============================] - 82s 436ms/step - loss: 2.0640 - sparse_categorical_accuracy: 0.2260 - val_loss: 2.1994 - val_sparse_categorical_accuracy: 0.1860
# Epoch 21/50
# 188/188 [==============================] - 123s 653ms/step - loss: 1.9699 - sparse_categorical_accuracy: 0.2557 - val_loss: 2.1702 - val_sparse_categorical_accuracy: 0.2000
# Epoch 22/50
# 188/188 [==============================] - 121s 647ms/step - loss: 1.8757 - sparse_categorical_accuracy: 0.3047 - val_loss: 2.1341 - val_sparse_categorical_accuracy: 0.2315
# Epoch 23/50
# 188/188 [==============================] - 122s 651ms/step - loss: 1.7067 - sparse_categorical_accuracy: 0.3660 - val_loss: 2.0864 - val_sparse_categorical_accuracy: 0.2690
# Epoch 24/50
# 188/188 [==============================] - 81s 433ms/step - loss: 1.5190 - sparse_categorical_accuracy: 0.4357 - val_loss: 2.1305 - val_sparse_categorical_accuracy: 0.2725
# Epoch 25/50
# 188/188 [==============================] - 122s 651ms/step - loss: 1.3111 - sparse_categorical_accuracy: 0.5117 - val_loss: 2.0804 - val_sparse_categorical_accuracy: 0.2800
# Epoch 26/50
# 188/188 [==============================] - 81s 432ms/step - loss: 1.1061 - sparse_categorical_accuracy: 0.5983 - val_loss: 2.1465 - val_sparse_categorical_accuracy: 0.2870
# Epoch 27/50
# 188/188 [==============================] - 81s 431ms/step - loss: 0.9149 - sparse_categorical_accuracy: 0.6702 - val_loss: 2.1012 - val_sparse_categorical_accuracy: 0.3095
# Epoch 28/50
# 188/188 [==============================] - 86s 458ms/step - loss: 0.7386 - sparse_categorical_accuracy: 0.7433 - val_loss: 2.1630 - val_sparse_categorical_accuracy: 0.3265
# Epoch 29/50
# 188/188 [==============================] - 81s 430ms/step - loss: 0.5928 - sparse_categorical_accuracy: 0.7953 - val_loss: 2.1872 - val_sparse_categorical_accuracy: 0.3230
# Epoch 30/50
# 188/188 [==============================] - 81s 430ms/step - loss: 0.4913 - sparse_categorical_accuracy: 0.8328 - val_loss: 2.2515 - val_sparse_categorical_accuracy: 0.3220
# Epoch 31/50
# 188/188 [==============================] - 86s 455ms/step - loss: 0.4105 - sparse_categorical_accuracy: 0.8653 - val_loss: 2.1830 - val_sparse_categorical_accuracy: 0.3345
# Epoch 32/50
# 188/188 [==============================] - 81s 428ms/step - loss: 0.3276 - sparse_categorical_accuracy: 0.8988 - val_loss: 2.2151 - val_sparse_categorical_accuracy: 0.3495
# Epoch 33/50
# 188/188 [==============================] - 81s 429ms/step - loss: 0.2941 - sparse_categorical_accuracy: 0.9073 - val_loss: 2.1907 - val_sparse_categorical_accuracy: 0.3485
# Epoch 34/50
# 188/188 [==============================] - 80s 427ms/step - loss: 0.2428 - sparse_categorical_accuracy: 0.9237 - val_loss: 2.2416 - val_sparse_categorical_accuracy: 0.3545
# Epoch 35/50
# 188/188 [==============================] - 81s 431ms/step - loss: 0.2143 - sparse_categorical_accuracy: 0.9333 - val_loss: 2.3265 - val_sparse_categorical_accuracy: 0.3430
#
# Complete

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()

# %% [markdown]
# # 모델 테스트

# %%
saved_model_path = model_dir_name + 'fashion_classification_female_0125_06.keras'

saved_model = keras.models.load_model(saved_model_path)

# %%
saved_model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 200, 200, 3)]     0
#
#  conv2d_8 (Conv2D)           (None, 200, 200, 64)      4864
#
#  dropout_9 (Dropout)         (None, 200, 200, 64)      0
#
#  conv2d_9 (Conv2D)           (None, 200, 200, 64)      36928
#
#  max_pooling2d_4 (MaxPoolin  (None, 100, 100, 64)      0
#  g2D)
#
#  conv2d_10 (Conv2D)          (None, 100, 100, 128)     73856
#
#  dropout_10 (Dropout)        (None, 100, 100, 128)     0
#
#  conv2d_11 (Conv2D)          (None, 100, 100, 128)     147584
#
#  max_pooling2d_5 (MaxPoolin  (None, 50, 50, 128)       0
#  g2D)
#
#  conv2d_12 (Conv2D)          (None, 50, 50, 256)       295168
#
#  dropout_11 (Dropout)        (None, 50, 50, 256)       0
#
#  conv2d_13 (Conv2D)          (None, 50, 50, 256)       590080
#
#  max_pooling2d_6 (MaxPoolin  (None, 25, 25, 256)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 512)       1180160
#
#  dropout_12 (Dropout)        (None, 25, 25, 512)       0
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 512)       2359808
#
#  max_pooling2d_7 (MaxPoolin  (None, 12, 12, 512)       0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 73728)             0
#
#  dense_5 (Dense)             (None, 1000)              73729000
#
#  dropout_13 (Dropout)        (None, 1000)              0
#
#  dense_6 (Dense)             (None, 1000)              1001000
#
#  dropout_14 (Dropout)        (None, 1000)              0
#
#  dense_7 (Dense)             (None, 1000)              1001000
#
#  dropout_15 (Dropout)        (None, 1000)              0
#
#  dense_8 (Dense)             (None, 1000)              1001000
#
#  dropout_16 (Dropout)        (None, 1000)              0
#
#  dense_9 (Dense)             (None, 1000)              1001000
#
#  dropout_17 (Dropout)        (None, 1000)              0
#
#  OutputLayer (Dense)         (None, 10)                10010
#
# =================================================================
# Total params: 82431458 (314.45 MB)
# Trainable params: 82431458 (314.45 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ## 1개 Test 데이터 예측결과 확인

# %%
num = random.randint(0, 1999)
print("Random Number : ", num)

preds = saved_model.predict(x_test[num:num+1])
type(preds)

# %%
true_label = label_name[y_test[num]]
pred_label = label_name[np.argmax(preds)]

plt.imshow(x_test[num])
plt.show()

print('True Label : ', true_label)
print('Pred Label : ', pred_label)

# %% [markdown]
# ## 전체 Test 데이터 정확도 확인

# %%
 saved_model.evaluate(x_test, y_test)
# Out:
# 63/63 [==============================] - 6s 82ms/step - loss: 2.1099 - sparse_categorical_accuracy: 0.2520
# [2.109907865524292, 0.25200000405311584]
